# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/'

# %%
ua = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
page = requests.get(url, headers={"User-Agent": ua})

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!doctype html >\r\n<!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->\r\n<!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->\r\n<!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->\r\n<head><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Open+Sans%3A300italic%2C400%2C400italic%2C600%2C600italic%2C700%7CRoboto%3A300%2C400%2C400italic%2C500%2C500italic%2C700%2C900" />\r\n    <meta charset="UTF-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <link rel="pingback" href="https://insights.blackcoffer.com/xmlrpc.php" />\r\n    <meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<meta property="og:image" content="https://insights.blackcoffer.com/wp-content/uploads/2021/06/h12-slider-image-2.jpg" />\n\t<!-- This site is optimized with the Yoast SEO plugin v19.7.1 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>AI in healthcare to Imp
# ...

# %%
soup = BeautifulSoup(page.content,'html.parser')

# %%
article = soup.findAll(attrs = {'class': 'entry-title'})

# %%
#article = soup.findAll( attrs = {'id': 'td-outer-wrap'})
article
# Out:
# [<h3 class="entry-title td-module-title"><a href="https://insights.blackcoffer.com/medical-classification/" rel="bookmark" title="Medical Classification">Medical Classification</a></h3>,
#  <h3 class="entry-title td-module-title"><a href="https://insights.blackcoffer.com/design-develop-bert-question-answering-model-explanations-with-visualization/" rel="bookmark" title="Design &amp; Develop BERT Question Answering model explanations with visualization">Design &amp; Develop BERT Question Answering model explanations with visualization</a></h3>,
#  <h3 class="entry-title td-module-title"><a href="https://insights.blackcoffer.com/design-and-develop-solution-to-anomaly-detection-classification-problems/" rel="bookmark" title="Design and develop solution to anomaly detection classification problems">Design and develop solution to anomaly detection classification problems</a></h3>,
# ...
